# %%
from urllib.request import urlopen 
from zipfile import ZipFile
import json 
import os
import re
import requests, io
import pandas as pd
import xml.etree.ElementTree as ET
from bs4 import BeautifulSoup

# %%
#url = "https://gbfs.divvybikes.com/gbfs/2.3/gbfs.json"
url = 'https://divvy-tripdata.s3.amazonaws.com'

# %%
response = requests.get(url)
if response.status_code != 200:
    print(f"Failed to retrieve XML page: {response.status_code}")
    exit()

# %%
#soup = BeautifulSoup(response.content, 'html.parser')
zip_urls = re.findall(r'([\w\-_]+\.zip)', response.text)

# %%
#zip_urls = [link['href'] for link in zip_links if link['href'].endswith('.zip')]
#zip_urls = [elem.text for elem in root.findall('')]

# %%
download_dir = 'downloaded_zips'
extracted_dir = 'extracted_files'

# %%
os.makedirs(download_dir, exist_ok=True)
os.makedirs(extracted_dir, exist_ok=True)

# %%
for zip_url in zip_urls:
    # The links on the page are relative, so prepend the base URL
    full_zip_url = f"https://divvy-tripdata.s3.amazonaws.com/{zip_url}"
    
    print(f"Downloading: {full_zip_url}")
    zip_response = requests.get(full_zip_url)
    
    if zip_response.status_code == 200:
        zip_filename = os.path.join(download_dir, zip_url.split('/')[-1])
        
        # Save the ZIP file to the local directory
        with open(zip_filename, 'wb') as zip_file:
            zip_file.write(zip_response.content)
        
        # Step 5: Extract the ZIP file
        with ZipFile(zip_filename, 'r') as zip_ref:
            print(f"Extracting: {zip_filename}")
            zip_ref.extractall(extracted_dir)
    else:
        print(f"Failed to download: {full_zip_url} - Status code: {zip_response.status_code}")
# Out:
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202004-divvy-tripdata.zip
# Extracting: downloaded_zips/202004-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202005-divvy-tripdata.zip
# Extracting: downloaded_zips/202005-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202006-divvy-tripdata.zip
# Extracting: downloaded_zips/202006-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202007-divvy-tripdata.zip
# Extracting: downloaded_zips/202007-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202008-divvy-tripdata.zip
# Extracting: downloaded_zips/202008-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202009-divvy-tripdata.zip
# Extracting: downloaded_zips/202009-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202010-divvy-tripdata.zip
# Extracting: downloaded_zips/202010-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202011-divvy-tripdata.zip
# Extracting: downloaded_zips/202011-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202012-divvy-tripdata.zip
# Extracting: downloaded_zips/202012-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202101-divvy-tripdata.zip
# Extracting: downloaded_zips/202101-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202102-divvy-tripdata.zip
# Extracting: downloaded_zips/202102-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202103-divvy-tripdata.zip
# Extracting: downloaded_zips/202103-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202104-divvy-tripdata.zip
# Extracting: downloaded_zips/202104-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202105-divvy-tripdata.zip
# Extracting: downloaded_zips/202105-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202106-divvy-tripdata.zip
# Extracting: downloaded_zips/202106-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202107-divvy-tripdata.zip
# Extracting: downloaded_zips/202107-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202108-divvy-tripdata.zip
# Extracting: downloaded_zips/202108-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202109-divvy-tripdata.zip
# Extracting: downloaded_zips/202109-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202110-divvy-tripdata.zip
# Extracting: downloaded_zips/202110-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202111-divvy-tripdata.zip
# Extracting: downloaded_zips/202111-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202112-divvy-tripdata.zip
# Extracting: downloaded_zips/202112-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202201-divvy-tripdata.zip
# Extracting: downloaded_zips/202201-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202202-divvy-tripdata.zip
# Extracting: downloaded_zips/202202-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202203-divvy-tripdata.zip
# Extracting: downloaded_zips/202203-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202204-divvy-tripdata.zip
# Extracting: downloaded_zips/202204-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202205-divvy-tripdata.zip
# Extracting: downloaded_zips/202205-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202206-divvy-tripdata.zip
# Extracting: downloaded_zips/202206-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202207-divvy-tripdata.zip
# Extracting: downloaded_zips/202207-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202208-divvy-tripdata.zip
# Extracting: downloaded_zips/202208-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202209-divvy-tripdata.zip
# Extracting: downloaded_zips/202209-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202210-divvy-tripdata.zip
# Extracting: downloaded_zips/202210-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202211-divvy-tripdata.zip
# Extracting: downloaded_zips/202211-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202212-divvy-tripdata.zip
# Extracting: downloaded_zips/202212-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202301-divvy-tripdata.zip
# Extracting: downloaded_zips/202301-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202302-divvy-tripdata.zip
# Extracting: downloaded_zips/202302-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202303-divvy-tripdata.zip
# Extracting: downloaded_zips/202303-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202304-divvy-tripdata.zip
# Extracting: downloaded_zips/202304-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202305-divvy-tripdata.zip
# Extracting: downloaded_zips/202305-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202306-divvy-tripdata.zip
# Extracting: downloaded_zips/202306-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202307-divvy-tripdata.zip
# Extracting: downloaded_zips/202307-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202308-divvy-tripdata.zip
# Extracting: downloaded_zips/202308-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202309-divvy-tripdata.zip
# Extracting: downloaded_zips/202309-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202310-divvy-tripdata.zip
# Extracting: downloaded_zips/202310-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202311-divvy-tripdata.zip
# Extracting: downloaded_zips/202311-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202312-divvy-tripdata.zip
# Extracting: downloaded_zips/202312-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202401-divvy-tripdata.zip
# Extracting: downloaded_zips/202401-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202402-divvy-tripdata.zip
# Extracting: downloaded_zips/202402-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202403-divvy-tripdata.zip
# Extracting: downloaded_zips/202403-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202404-divvy-tripdata.zip
# Extracting: downloaded_zips/202404-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202405-divvy-tripdata.zip
# Extracting: downloaded_zips/202405-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202406-divvy-tripdata.zip
# Extracting: downloaded_zips/202406-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202407-divvy-tripdata.zip
# Extracting: downloaded_zips/202407-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202408-divvy-tripdata.zip
# Extracting: downloaded_zips/202408-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/202409-divvy-tripdata.zip
# Extracting: downloaded_zips/202409-divvy-tripdata.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Stations_Trips_2013.zip
# Extracting: downloaded_zips/Divvy_Stations_Trips_2013.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Stations_Trips_2014_Q1Q2.zip
# Extracting: downloaded_zips/Divvy_Stations_Trips_2014_Q1Q2.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Stations_Trips_2014_Q3Q4.zip
# Extracting: downloaded_zips/Divvy_Stations_Trips_2014_Q3Q4.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2015-Q1Q2.zip
# Extracting: downloaded_zips/Divvy_Trips_2015-Q1Q2.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2015_Q3Q4.zip
# Extracting: downloaded_zips/Divvy_Trips_2015_Q3Q4.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2016_Q1Q2.zip
# Extracting: downloaded_zips/Divvy_Trips_2016_Q1Q2.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2016_Q3Q4.zip
# Extracting: downloaded_zips/Divvy_Trips_2016_Q3Q4.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2017_Q1Q2.zip
# Extracting: downloaded_zips/Divvy_Trips_2017_Q1Q2.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2017_Q3Q4.zip
# Extracting: downloaded_zips/Divvy_Trips_2017_Q3Q4.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2018_Q1.zip
# Extracting: downloaded_zips/Divvy_Trips_2018_Q1.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2018_Q2.zip
# Extracting: downloaded_zips/Divvy_Trips_2018_Q2.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2018_Q3.zip
# Extracting: downloaded_zips/Divvy_Trips_2018_Q3.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2018_Q4.zip
# Extracting: downloaded_zips/Divvy_Trips_2018_Q4.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2019_Q1.zip
# Extracting: downloaded_zips/Divvy_Trips_2019_Q1.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2019_Q2.zip
# Extracting: downloaded_zips/Divvy_Trips_2019_Q2.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_2019_Q3.zip
# Extracting: downloaded_zips/Divvy_Trips_2019_Q3.zip
# Downloading: https://divvy-tripdata.s3.amazonaws.com/Divvy_Trips_
Size><StorageClass>STANDARD</StorageClass></Contents><Contents><Key>202107-divvy-tripdata.zip</Key><LastModified>2021-08-14T06:06:49.000Z</LastModified><ETag>&quot;0042b93934a2af77fd46750effe17dc9-2&quot;</ETag><Size>29680807</Size><StorageClass>STANDARD</StorageClass></Contents><Contents><Key>202108-divvy-tripdata.zip</Key><LastModified>2021-09-08T18:10:46.000Z</LastModified><ETag>&quot;90b3b4665be43ffc3d45346d48c49ebb-2&quot;</ETag><Size>27875 ...

# %%
zip_urls
# Out:
# ['202004-divvy-tripdata.zip',
#  '202005-divvy-tripdata.zip',
#  '202006-divvy-tripdata.zip',
#  '202007-divvy-tripdata.zip',
#  '202008-divvy-tripdata.zip',
#  '202009-divvy-tripdata.zip',
#  '202010-divvy-tripdata.zip',
#  '202011-divvy-tripdata.zip',
#  '202012-divvy-tripdata.zip',
#  '202101-divvy-tripdata.zip',
#  '202102-divvy-tripdata.zip',
#  '202103-divvy-tripdata.zip',
#  '202104-divvy-tripdata.zip',
#  '202105-divvy-tripdata.zip',
#  '202106-divvy-tripdata.zip',
#  '202107-divvy-tripdata.zip',
#  '202108-divvy-tripdata.zip',
#  '202109-divvy-tripdata.zip',
#  '202110-divvy-tripdata.zip',
#  '202111-divvy-tripdata.zip',
#  '202112-divvy-tripdata.zip',
#  '202201-divvy-tripdata.zip',
#  '202202-divvy-tripdata.zip',
#  '202203-divvy-tripdata.zip',
#  '202204-divvy-tripdata.zip',
#  '202205-divvy-tripdata.zip',
#  '202206-divvy-tripdata.zip',
#  '202207-divvy-tripdata.zip',
#  '202208-divvy-tripdata.zip',
#  '202209-divvy-tripdata.zip',
#  '202210-divvy-tripdata.zip',
#  '202211-divvy-tripdata.zip',
#  '202212-divvy-tripdata.zip',
#  '202301-divvy-tripdata.zip',
#  '202302-divvy-tripdata.zip',
#  '202303-divvy-tripdata.zip',
#  '202304-divvy-tripdata.zip',
#  '202305-divvy-tripdata.zip',
#  '202306-divvy-tripdata.zip',
#  '202307-divvy-tripdata.zip',
#  '202308-divvy-tripdata.zip',
#  '202309-divvy-tripdata.zip',
#  '202310-divvy-tripdata.zip',
#  '202311-divvy-tripdata.zip',
#  '202312-divvy-tripdata.zip',
#  '202401-divvy-tripdata.zip',
#  '202402-divvy-tripdata.zip',
#  '202403-divvy-tripdata.zip',
#  '202404-divvy-tripdata.zip',
#  '202405-divvy-tripdata.zip',
#  '202406-divvy-tripdata.zip',
#  '202407-divvy-tripdata.zip',
#  '202408-divvy-tripdata.zip',
#  '202409-divvy-tripdata.zip',
#  'Divvy_Stations_Trips_2013.zip',
#  'Divvy_Stations_Trips_2014_Q1Q2.zip',
#  'Divvy_Stations_Trips_2014_Q3Q4.zip',
#  'Divvy_Trips_2015-Q1Q2.zip',
#  'Divvy_Trips_2015_Q3Q4.zip',
#  'Divvy_Trips_2016_Q1Q2.zip',
#  'Divvy_Trips_2016_Q3Q4.zip',
#  'Divvy_Trips_2017_Q1Q2.zip',
#  'Divvy_Trips_2017_Q3Q4.zip',
#  'Divvy_Trips_2018_Q1.zip',
#  'Divvy_Trips_2018_Q2.zip',
#  'Divvy_Trips_2018_Q3.zip',
#  'Divvy_Trips_2018_Q4.zip',
#  'Divvy_Trips_2019_Q1.zip',
#  'Divvy_Trips_2019_Q2.zip',
#  'Divvy_Trips_2019_Q3.zip',
#  'Divvy_Trips_2019_Q4.zip',
#  'Divvy_Trips_2020_Q1.zip']
